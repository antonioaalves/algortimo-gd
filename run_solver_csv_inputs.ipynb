# %%
import os
import pandas as pd
import datetime as dt
import numpy as np
from src.configuration_manager.manager import ConfigurationManager

config_manager = ConfigurationManager()
path_os = os.path.join(config_manager.system.project_root_dir, 'data', 'output')
posto_id = '1041'
process_id = '17371'
df_calendario = pd.read_csv(os.path.join(path_os, 'df_calendario-'+process_id+'-'+posto_id+'.csv'))
df_estimativas = pd.read_csv(os.path.join(path_os, 'df_estimativas-'+process_id+'-'+posto_id+'.csv'))
df_colaborador = pd.read_csv(os.path.join(path_os, 'df_colaborador-'+process_id+'-'+posto_id+'.csv'))
# Out:
# 2026-01-08 17:11:23,240 |     INFO | Logger initialized for algoritmo_GD
# 2026-01-08 17:11:23,242 |     INFO | System configuration loaded for project: algoritmo_GD
# 2026-01-08 17:11:23,242 |     INFO | System configuration validation passed
# 2026-01-08 17:11:23,242 |     INFO | Database configuration validation passed
# 2026-01-08 17:11:23,242 |     INFO | Database configuration loaded for environment: salsa_prd
# 2026-01-08 17:11:23,242 |     INFO | Database config loaded successfully
# 2026-01-08 17:11:23,242 |     INFO | Database config: DatabaseConfig(host='10.175.23.27', port=1523, service='WFM_SALSA01.database.backbone.oraclevcn.com', user='FRANCISCO_VIEIRA', environment='salsa_prd')
# 2026-01-08 17:11:23,242 |     INFO | Database connection URL generated successfully
# 2026-01-08 17:11:23,242 |     INFO | Database config: oracle+cx_oracle://FRANCISCO_VIEIRA:TL[nt!c.0043@10.175.23.27:1523/?service_name=WFM_SALSA01.database.backbone.oraclevcn.com
# 2026-01-08 17:11:23,248 |     INFO | Path hierarchy loaded successfully
# 2026-01-08 17:11:23,249 |     INFO | Path hierarchy validation passed
# 2026-01-08 17:11:23,250 |     INFO | Loading SQL-based path configuration
# 2026-01-08 17:11:23,251 |     INFO | SQL paths validation passed
# 2026-01-08 17:11:23,253 |     INFO | SQL paths loaded successfully
# 2026-01-08 17:11:23,253 |     INFO | Paths configuration loaded (use_db=True)
# 2026-01-08 17:11:23,253 |     INFO | Parameters configuration file loaded successfully
# 2026-01-08 17:11:23,253 |     INFO | Parameters configuration validation passed
# 2026-01-08 17:11:23,255 |     INFO | Parameters configuration loaded successfully
# 2026-01-08 17:11:23,256 |     INFO | Algorithm component configuration loaded successfully
# 2026-01-08 17:11:23,258 |     INFO | Stages configuration imported successfully
# 2026-01-08 17:11:23,259 |     INFO | Stages configuration validation passed
# 2026-01-08 17:11:23,260 |     INFO | Stages configuration loaded successfully
# 2026-01-08 17:11:23,261 |     INFO | ConfigurationManager initialization completed successfully
# 2026-01-08 17:11:23,261 |     INFO | Starting comprehensive configuration validation
# 2026-01-08 17:11:23,262 |     INFO | All configuration validations passed

# %%
### Algorithm run

from src.algorithms.salsaAlgorithm import SalsaAlgorithm

algorithm = SalsaAlgorithm(
    parameters={},
    algo_name='salsa_algorithm',
    project_name='algortimo-gd',
    process_id=17371,
    start_date='2026-01-01',
    end_date='2026-12-31',
    #wfm_proc_colab= 2412,
)
medium_dataframes = {
    'df_calendario': df_calendario,
    'df_estimativas': df_estimativas,
    'df_colaborador': df_colaborador,
}
results = algorithm.run(
    data=medium_dataframes,
    algorithm_treatment_params={
                'admissao_proporcional': None,
                'NUM_DIAS_CONS': 7,
                'wfm_proc_colab': None,
                'start_date': "2026-01-01",
                'start_date': "2026-12-31",
    }
)
# Out:
# 2026-01-08 17:11:23,336 |     INFO | System configuration loaded for project: algoritmo_GD
# 2026-01-08 17:11:23,349 |     INFO | System configuration validation passed
# 2026-01-08 17:11:23,350 |     INFO | Database configuration validation passed
# 2026-01-08 17:11:23,351 |     INFO | Database configuration loaded for environment: salsa_prd
# 2026-01-08 17:11:23,351 |     INFO | Database config loaded successfully
# 2026-01-08 17:11:23,351 |     INFO | Database config: DatabaseConfig(host='10.175.23.27', port=1523, service='WFM_SALSA01.database.backbone.oraclevcn.com', user='FRANCISCO_VIEIRA', environment='salsa_prd')
# 2026-01-08 17:11:23,351 |     INFO | Database connection URL generated successfully
# 2026-01-08 17:11:23,351 |     INFO | Database config: oracle+cx_oracle://FRANCISCO_VIEIRA:TL[nt!c.0043@10.175.23.27:1523/?service_name=WFM_SALSA01.database.backbone.oraclevcn.com
# 2026-01-08 17:11:23,351 |     INFO | Path hierarchy loaded successfully
# 2026-01-08 17:11:23,351 |     INFO | Path hierarchy validation passed
# 2026-01-08 17:11:23,351 |     INFO | Loading SQL-based path configuration
# 2026-01-08 17:11:23,351 |     INFO | SQL paths validation passed
# 2026-01-08 17:11:23,351 |     INFO | SQL paths loaded successfully
# 2026-01-08 17:11:23,351 |     INFO | Paths configuration loaded (use_db=True)
# 2026-01-08 17:11:23,351 |     INFO | Parameters configuration file loaded successfully
# 2026-01-08 17:11:23,351 |     INFO | Parameters configuration validation passed
# 2026-01-08 17:11:23,351 |     INFO | Parameters configuration loaded successfully
# 2026-01-08 17:11:23,351 |     INFO | Algorithm component configuration loaded successfully
# 2026-01-08 17:11:23,351 |     INFO | Stages configuration imported successfully
# 2026-01-08 17:11:23,351 |     INFO | Stages configuration validation passed
# 2026-01-08 17:11:23,351 |     INFO | Stages configuration loaded successfully
# 2026-01-08 17:11:23,351 |     INFO | ConfigurationManager initialization completed successfully
# 2026-01-08 17:11:23,351 |     INFO | Starting comprehensive configuration validation
# 2026-01-08 17:11:23,351 |     INFO | All configuration validations passed
# 2026-01-08 17:11:23,943 |     INFO | Project root directory: {'data': {'csvs': {}, 'intermediate': {}, 'output': {}, 'Queries': {'GlobalData': {}, 'sql': {}, 'WFM_Process': {}}, 'logs': {}}, 'src': {'configuration_manager': {'config': {}, 'path_config': {}, 'parameter_config': {}}, 'algorithms': {'model_alcampo': {}, 'model_salsa': {}, 'model_salsa_v2': {}, 'R_algorithms': {}, 'shift_scheduler': {}, 'solver': {}}, 'get_functions': {}, 'load_csv_functions': {}}}
# 2026-01-08 17:11:23,946 |     INFO | Logger initialized for algortimo-gd
# 2026-01-08 17:11:23,946 |     INFO | Initialized algorithm: salsa_algorithm
# 2026-01-08 17:11:23,947 |     INFO | Initialized salsa_algorithm with parameters: {'shifts': ['M', 'T', 'L', 'LQ', 'LD', 'F', 'A', 'V', '-'], 'check_shifts': ['M', 'T', 'L', 'LQ', 'LD'], 'working_shifts': ['M', 'T', 'LD'], 'real_working_shifts': ['M', 'T'], 'settings': {'F_special_day': False, 'free_sundays_plus_c2d': False, 'missing_days_afect_free_days': False}}
# 2026-01-08 17:11:23,948 |     INFO | Starting execution of algorithm: salsa_algorithm
# 2026-01-08 17:11:23,949 |     INFO | Stage 1: Adapting data
# 2026-01-08 17:11:23,949 |     INFO | Starting data adaptation for SALSA algorithm
# 2026-01-08 17:11:23,950 |     INFO | Using algorithm treatment parameters: ['admissao_proporcional', 'NUM_DIAS_CONS', 'wfm_proc_colab', 'start_date']
# 2026-01-08 17:11:23,951 |     INFO | Input data structure: ['df_calendario', 'df_estimativas', 'df_colaborador']
# 2026-01-08 17:11:23,951 |     INFO | Using direct DataFrame structure
# 2026-01-08 17:11:23,951 |     INFO | Calling SALSA data processing function
# 2026-01-08 17:11:23,951 |     INFO | Starting enhanced data reading for salsa algorithm
# 2026-01-08 17:11:23,951 |     INFO | algorithm_treatment_params: {'admissao_proporcional': None, 'NUM_DIAS_CONS': 7, 'wfm_proc_colab': None, 'start_date': '2026-12-31'}
# 2026-01-08 17:11:23,951 |    ERROR | Error in read_data_salsa: 'df_feriados'
# Traceback (most recent call last):
#   File "c:\Users\francisco.vieira\Documents\GitHub\algortimo-gd\src\algorithms\model_salsa\read_salsa.py", line 40, in read_data_salsa
#     matriz_feriados_gd = algorithm_treatment_params['df_feriados'].copy()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'df_feriados'
# 2026-01-08 17:11:23,951 |    ERROR | Error in data adaptation: 'df_feriados'
# Traceback (most recent call last):
#   File "c:\Users\francisco.vieira\Documents\GitHub\algortimo-gd\src\algorithms\salsaAlgorithm.py", line 172, in adapt_data
#     processed_data = read_data_salsa(medium_dataframes, algorithm_treatment_params)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\francisco.vieira\Documents\GitHub\algortimo-gd\src\algorithms\model_salsa\read_salsa.py", line 40, in read_data_salsa
#     matriz_feriados_gd = algorithm_treatment_params['df_feriados'].copy()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'df_feriados'
# 2026-01-08 17:11:23,951 |    ERROR | Error in algorithm salsa_algorithm: 'df_feriados'
# 2026-01-08 17:11:23,951 |    ERROR | Traceback (most recent call last):
#   File "c:\Users\francisco.vieira\Documents\GitHub\algortimo-gd\.venv\Lib\site-packages\base_data_project\algorithms\base.py", line 120, in run
#     adapted_data = self.adapt_data(data, algorithm_treatment_params)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\francisco.vieira\Documents\GitHub\algortimo-gd\src\algorithms\salsaAlgorithm.py", line 172, in adapt_data
#     processed_data = read_data_salsa(medium_dataframes, algorithm_treatment_params)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\francisco.vieira\Documents\GitHub\algortimo-gd\src\algorithms\model_salsa\read_salsa.py", line 40, in read_data_salsa
#     matriz_feriados_gd = algorithm_treatment_params['df_feriados'].copy()
#                          ~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^
# KeyError: 'df_feriados'
