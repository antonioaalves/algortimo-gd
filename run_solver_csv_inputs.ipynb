# %%
import os
import pandas as pd
import datetime as dt
import numpy as np
from src.config import ROOT_DIR, CONFIG

path_os = os.path.join(ROOT_DIR, 'data', 'output')
posto_id = '562'
process_id = '4984'
df_calendario = pd.read_csv(os.path.join(path_os, 'df_calendario-'+process_id+'-'+posto_id+'.csv'))
df_estimativas = pd.read_csv(os.path.join(path_os, 'df_estimativas-'+process_id+'-'+posto_id+'.csv'))
df_colaborador = pd.read_csv(os.path.join(path_os, 'df_colaborador-'+process_id+'-'+posto_id+'.csv'))
# Out:
# 2025-10-09 09:45:48,084 |     INFO | Logger initialized for algoritmo_GD

# %%
### Algorithm run

from src.algorithms.salsaAlgorithm import SalsaAlgorithm

algorithm = SalsaAlgorithm(
    parameters={},
    algo_name='salsa_algorithm',
    project_name='algortimo-gd',
    process_id=4984,
    start_date='2025-01-01',
    end_date='2025-12-31',
    #wfm_proc_colab= 2412,
)
medium_dataframes = {
    'df_calendario': df_calendario,
    'df_estimativas': df_estimativas,
    'df_colaborador': df_colaborador,
}
results = algorithm.run(
    data=medium_dataframes,
    algorithm_treatment_params={
            'treatment_params': {
                'admissao_proporcional': None,
            },
            'constraint_params': {
                'NUM_DIAS_CONS': 6,
            },
    }
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 ### Algorithm run
#       3 from src.algorithms.salsaAlgorithm import SalsaAlgorithm
# ----> 5 algorithm = SalsaAlgorithm(
#       6     parameters={},
#       7     algo_name='salsa_algorithm',
#       8     project_name='algortimo-gd',
#       9     process_id=4984,
#      10     start_date='2025-01-01',
#      11     end_date='2025-12-31',
#      12     wfm_proc_colab= 2412,
#      13 )
#      14 medium_dataframes = {
#      15     'df_calendario': df_calendario,
#      16     'df_estimativas': df_estimativas,
#      17     'df_colaborador': df_colaborador,
#      18 }
#      19 results = algorithm.run(
#      20     data=medium_dataframes,
#      21     algorithm_treatment_params={
#    (...)     28     }
#      29 )
#
# TypeError: SalsaAlgorithm.__init__() got an unexpected keyword argument 'wfm_proc_colab'
