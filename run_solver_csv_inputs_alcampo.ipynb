# %%
import os
import pandas as pd
import datetime as dt
import numpy as np
from src.configuration_manager.manager import ConfigurationManager

config_manager = ConfigurationManager()
path_os = os.path.join(config_manager.system.project_root_dir, 'data', 'output')
posto_id = '998'
process_id = '62817'
df_calendario = pd.read_csv(os.path.join(path_os, 'df_calendario-'+process_id+'-'+posto_id+'.csv'))
df_estimativas = pd.read_csv(os.path.join(path_os, 'df_estimativas-'+process_id+'-'+posto_id+'.csv'))
df_colaborador = pd.read_csv(os.path.join(path_os, 'df_colaborador-'+process_id+'-'+posto_id+'.csv'))
# Out:
# 2026-08-10 09:51:09,222 |     INFO | Logger initialized for algoritmo_GD
# 2026-08-10 09:51:09,223 |     INFO | System configuration loaded for project: algoritmo_GD
# 2026-08-10 09:51:09,223 |     INFO | System configuration validation passed
# 2026-08-10 09:51:09,225 |  WARNING | Using legacy oracle_connection_parameters.json; migrate to ORACLE_DB_* environment variables.
# 2026-08-10 09:51:09,225 |     INFO | Database configuration validation passed
# 2026-08-10 09:51:09,228 |     INFO | Database configuration loaded for environment: salsa_prd
# 2026-08-10 09:51:09,228 |     INFO | Database config loaded successfully
# 2026-08-10 09:51:09,228 |     INFO | Database config: DatabaseConfig(host='10.175.23.27', port=1523, service='WFM_SALSA01.database.backbone.oraclevcn.com', user='FRANCISCO_VIEIRA', environment='salsa_prd')
# 2026-08-10 09:51:09,229 |     INFO | Database connection URL generated successfully
# ...

# %%
### Algorithm run

from src.algorithms.alcampoAlgorithm import AlcampoAlgorithm

algorithm = AlcampoAlgorithm(
    parameters={},
    algo_name='alcampo_algorithm',
    project_name='algortimo-gd',
    process_id=process_id,
    start_date='2027-01-01',
    end_date='2027-12-31',
)
medium_dataframes = {
    'df_calendario': df_calendario,
    'df_estimativas': df_estimativas,
    'df_colaborador': df_colaborador,
}

results = algorithm.run(
    data=medium_dataframes,
    algorithm_treatment_params={
                'admissao_proporcional': None,
                'NUM_DIAS_CONS': 10,
                'wfm_proc_colab': None,
                'df_feriados': pd.DataFrame([
                                ["2026-12-25","F",2935,None,None,None,  5,5,52,"Fri",2026],
                                ["2026-12-26","A",2935,None,None,None,  6,6,52,"Sat",2026],
                                ["2027-01-01","A",2935,None,None,None, 12,5,53,"Fri",2027],
                                ["2027-03-17","A",2935,None,None,None, 87,3,11,"Wed",2027],
                                ["2027-12-25","F",2935,None,None,None,370,6,51,"Sat",2027],
                                ["2028-01-01","A",2935,None,None,None,377,6,52,"Sat",2028],
                            ], columns=[
                                "schedule_day","tipo_feriado","fk_unidade","fk_cidade",
                                "fk_estado","fk_pais","index","wday","ww","wd","year"
                            ]),
                'nome_pais': 'Espanha',
                'eci_flag': False, 
                'eci_sibling_results_flag': False,
                "start_date": "2027-01-01",
                "end_date": "2027-12-31",
                "ld_holiday_param" : 0,
                "ld_sunday_param" : 0,
                "df_process_rules": None,
                "df_process_rules": None,
                'df_annual_variables': pd.DataFrame([
                                [10041,"2027-01-01","2027-12-31",0.0,0.0,0.0,0.0,2027.0,False,False,False,False],
                                [ 6834,"2027-01-01","2027-8-30",15.0,5.0,0.0,0.0,2027.0,True,False,False,False],
                                [ 6834,"2027-09-01","2027-12-31",15.0,5.0,0.0,0.0,2027.0,False,True,False,False],
                                [ 6838,"2027-01-01","2027-12-31",0.0,0.0,0.0,0.0,2027.0,False,False,False,False],
                                [ 6842,"2027-01-01","2027-12-31",0.0,0.0,0.0,0.0,2027.0,False,False,False,False],
                                [ 6948,"2027-01-01","2027-12-31",0.0,0.0,0.0,0.0,2027.0,False,False,False,False],
                                [ 9541,"2027-01-01","2027-12-31",0.0,0.0,0.0,0.0,2027.0,False,False,False,False],
                            ], columns=[
                                "employee_id", "begin_date", "end_date", "l_dom", "c2d", "l_sab", "l_dom_or_sab", "year", "apply_l_dom", "apply_c2d", "apply_l_sab", "apply_l_dom_or_sab"
                            ]),
    }
)
# Out:
# 2026-08-10 09:51:09,327 |     INFO | System configuration loaded for project: algoritmo_GD
# 2026-08-10 09:51:09,328 |     INFO | System configuration validation passed
# 2026-08-10 09:51:09,328 |  WARNING | Using legacy oracle_connection_parameters.json; migrate to ORACLE_DB_* environment variables.
# 2026-08-10 09:51:09,328 |     INFO | Database configuration validation passed
# 2026-08-10 09:51:09,328 |     INFO | Database configuration loaded for environment: salsa_prd
# 2026-08-10 09:51:09,328 |     INFO | Database config loaded successfully
# 2026-08-10 09:51:09,328 |     INFO | Database config: DatabaseConfig(host='10.175.23.27', port=1523, service='WFM_SALSA01.database.backbone.oraclevcn.com', user='FRANCISCO_VIEIRA', environment='salsa_prd')
# 2026-08-10 09:51:09,328 |     INFO | Database connection URL generated successfully
# ...
