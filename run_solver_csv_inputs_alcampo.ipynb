# %%
import os
import pandas as pd
import datetime as dt
import numpy as np
from src.configuration_manager.manager import ConfigurationManager

config_manager = ConfigurationManager()
path_os = os.path.join(config_manager.system.project_root_dir, 'data', 'output')
posto_id = '998'
process_id = '62817'
df_calendario = pd.read_csv(os.path.join(path_os, 'df_calendario-'+process_id+'-'+posto_id+'.csv'))
df_estimativas = pd.read_csv(os.path.join(path_os, 'df_estimativas-'+process_id+'-'+posto_id+'.csv'))
df_colaborador = pd.read_csv(os.path.join(path_os, 'df_colaborador-'+process_id+'-'+posto_id+'.csv'))
df_annual_variables = pd.read_csv(os.path.join(path_os, 'df_annual_variables-'+process_id+'-'+posto_id+'.csv'))
# Out:
# 2026-08-27 17:08:50,655 |     INFO | Logger initialized for algoritmo_GD
# 2026-08-27 17:08:50,665 |     INFO | System configuration loaded for project: algoritmo_GD
# 2026-08-27 17:08:50,665 |     INFO | System configuration validation passed
# 2026-08-27 17:08:50,667 |  WARNING | Using legacy oracle_connection_parameters.json; migrate to ORACLE_DB_* environment variables.
# 2026-08-27 17:08:50,667 |     INFO | Database configuration validation passed
# 2026-08-27 17:08:50,678 |     INFO | Database configuration loaded for environment: salsa_prd
# 2026-08-27 17:08:50,678 |     INFO | Database config loaded successfully
# 2026-08-27 17:08:50,678 |     INFO | Database config: DatabaseConfig(host='10.175.23.27', port=1523, service='WFM_SALSA01.database.backbone.oraclevcn.com', user='FRANCISCO_VIEIRA', environment='salsa_prd')
# 2026-08-27 17:08:50,678 |     INFO | Database connection URL generated successfully
# ...

# %%
### Algorithm run

from src.algorithms.alcampoAlgorithm import AlcampoAlgorithm

algorithm = AlcampoAlgorithm(
    parameters={},
    algo_name='alcampo_algorithm',
    project_name='algortimo-gd',
    process_id=process_id,
    start_date='2026-01-01',
    end_date='2026-12-31',
)
medium_dataframes = {
    'df_calendario': df_calendario,
    'df_estimativas': df_estimativas,
    'df_colaborador': df_colaborador,
}

results = algorithm.run(
    data=medium_dataframes,
    algorithm_treatment_params={
        'admissao_proporcional': None,
        'NUM_DIAS_CONS': 10,
        'wfm_proc_colab': None,
        'df_feriados': pd.DataFrame([
                        ["2025-12-25","F",2935,None,None,None,  3,5,52,"Fri",2025],
                        ["2025-12-26","A",2935,None,None,None,  4,6,52,"Sat",2025],
                        ["2026-01-01","F",2935,None,None,None, 11,5,53,"Fri",2026],
                        ["2026-03-17","A",2935,None,None,None, 86,3,11,"Wed",2026],
                        ["2026-04-30","A",2935,None,None,None,130,3,11,"Wed",2026],
                        ["2026-05-07","A",2935,None,None,None,137,3,11,"Wed",2026],
                        ["2026-05-14","A",2935,None,None,None,144,3,11,"Wed",2026],
                        ["2026-06-10","F",2935,None,None,None,171,5,52,"Fri",2026],
                        ["2026-12-25","F",2935,None,None,None,369,6,51,"Sat",2026],
                        ["2027-01-01","F",2935,None,None,None,376,6,52,"Sat",2027],
                    ], columns=[
                        "schedule_day","tipo_feriado","fk_unidade","fk_cidade",
                        "fk_estado","fk_pais","index","wday","ww","wd","year"
                    ]),
        'nome_pais': 'Espanha',
        'eci_flag': False, 
        'eci_sibling_results_flag': False,
        "start_date": "2026-01-01",
        "end_date": "2026-12-31",
        "ld_holiday_param" : 0,
        "ld_sunday_param" : 0,
        "df_process_rules": None,
        "df_process_rules": None,
        'df_annual_variables': df_annual_variables
    }
)
# Out:
# 2026-08-27 17:08:50,800 |     INFO | System configuration loaded for project: algoritmo_GD
# 2026-08-27 17:08:50,800 |     INFO | System configuration validation passed
# 2026-08-27 17:08:50,800 |  WARNING | Using legacy oracle_connection_parameters.json; migrate to ORACLE_DB_* environment variables.
# 2026-08-27 17:08:50,800 |     INFO | Database configuration validation passed
# 2026-08-27 17:08:50,804 |     INFO | Database configuration loaded for environment: salsa_prd
# 2026-08-27 17:08:50,805 |     INFO | Database config loaded successfully
# 2026-08-27 17:08:50,806 |     INFO | Database config: DatabaseConfig(host='10.175.23.27', port=1523, service='WFM_SALSA01.database.backbone.oraclevcn.com', user='FRANCISCO_VIEIRA', environment='salsa_prd')
# 2026-08-27 17:08:50,807 |     INFO | Database connection URL generated successfully
# ...
